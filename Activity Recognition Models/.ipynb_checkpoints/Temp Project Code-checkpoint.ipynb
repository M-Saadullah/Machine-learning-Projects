# %%
# !pip install numpy scipy statsmodels
# Out:
# Requirement already satisfied: numpy in c:\users\inzi4\anaconda3\envs\tensorflow\lib\site-packages (1.24.3)
# Requirement already satisfied: scipy in c:\users\inzi4\anaconda3\envs\tensorflow\lib\site-packages (1.10.1)
# Collecting statsmodels
#   Downloading statsmodels-0.14.1-cp38-cp38-win_amd64.whl.metadata (9.8 kB)
# Collecting pandas!=2.1.0,>=1.0 (from statsmodels)
#   Downloading pandas-2.0.3-cp38-cp38-win_amd64.whl.metadata (18 kB)
# Collecting patsy>=0.5.4 (from statsmodels)
#   Downloading patsy-0.5.6-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: packaging>=21.3 in c:\users\inzi4\anaconda3\envs\tensorflow\lib\site-packages (from statsmodels) (23.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\inzi4\anaconda3\envs\tensorflow\lib\site-packages (from pandas!=2.1.0,>=1.0->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\inzi4\anaconda3\envs\tensorflow\lib\site-packages (from pandas!=2.1.0,>=1.0->statsmodels) (2024.1)
# Collecting tzdata>=2022.1 (from pandas!=2.1.0,>=1.0->statsmodels)
#   Downloading tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six in c:\users\inzi4\anaconda3\envs\tensorflow\lib\site-packages (from patsy>=0.5.4->statsmodels) (1.16.0)
# Downloading statsmodels-0.14.1-cp38-cp38-win_amd64.whl (10.0 MB)
#    ---------------------------------------- 0.0/10.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.0 MB 435.7 kB/s eta 0:00:23
#    ---------------------------------------- 0.1/10.0 MB 409.6 kB/s eta 0:00:25
#    ---------------------------------------- 0.1/10.0 MB 476.3 kB/s eta 0:00:21
#    ---------------------------------------- 0.1/10.0 MB 450.6 kB/s eta 0:00:22
#     --------------------------------------- 0.2/10.0 MB 687.0 kB/s eta 0:00:15
#    - -------------------------------------- 0.3/10.0 MB 737.3 kB/s eta 0:00:14
#    - -------------------------------------- 0.5/10.0 MB 1.0 MB/s eta 0:00:10
#    -- ------------------------------------- 0.6/10.0 MB 1.1 MB/s eta 0:00:09
#    -- ------------------------------------- 0.7/10.0 MB 1.3 MB/s eta 0:00:08
#    --- ------------------------------------ 0.8/10.0 MB 1.3 MB/s eta 0:00:08
#    --- ------------------------------------ 0.8/10.0 MB 1.3 MB/s eta 0:00:07
#    --- ------------------------------------ 0.9/10.0 MB 1.4 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.1/10.0 MB 1.5 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.2/10.0 MB 1.5 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.4/10.0 MB 1.7 MB/s eta 0:00:06
#    ------ --------------------------------- 1.6/10.0 MB 1.8 MB/s eta 0:00:05
#    ------ --------------------------------- 1.6/10.0 MB 1.7 MB/s eta 0:00:05
#    ------ --------------------------------- 1.6/10.0 MB 1.7 MB/s eta 0:00:05
#    ------ --------------------------------- 1.6/10.0 MB 1.7 MB/s eta 0:00:05
#    ------ --------------------------------- 1.6/10.0 MB 1.7 MB/s eta 0:00:05
#    ------ --------------------------------- 1.6/10.0 MB 1.7 MB/s eta 0:00:05
#    ------ --------------------------------- 1.6/10.0 MB 1.7 MB/s eta 0:00:05
#    ------ --------------------------------- 1.6/10.0 MB 1.7 MB/s eta 0:00:05
#    --------- ------------------------------ 2.4/10.0 MB 1.9 MB/s eta 0:00:05
#    ----------- ---------------------------- 2.8/10.0 MB 2.0 MB/s eta 0:00:04
#    ----------- ---------------------------- 2.8/10.0 MB 2.0 MB/s eta 0:00:04
#    ----------- ---------------------------- 2.9/10.0 MB 2.0 MB/s eta 0:00:04
#    ----------- ---------------------------- 3.0/10.0 MB 2.0 MB/s eta 0:00:04
#    ------------ --------------------------- 3.0/10.0 MB 2.0 MB/s eta 0:00:04
#    ------------ --------------------------- 3.1/10.0 MB 2.0 MB/s eta 0:00:04
#    ------------ --------------------------- 3.2/10.0 MB 2.0 MB/s eta 0:00:04
#    ------------ --------------------------- 3.2/10.0 MB 1.9 MB/s eta 0:00:04
#    ------------ --------------------------- 3.3/10.0 MB 1.8 MB/s eta 0:00:04
#    ------------- -------------------------- 3.3/10.0 MB 1.8 MB/s eta 0:00:04
#    ------------- -------------------------- 3.4/10.0 MB 1.8 MB/s eta 0:00:04
#    ------------- -------------------------- 3.4/10.0 MB 1.8 MB/s eta 0:00:04
#    ------------- -------------------------- 3.5/10.0 MB 1.7 MB/s eta 0:00:04
#    -------------- ------------------------- 3.6/10.0 MB 1.7 MB/s eta 0:00:04
#    -------------- ------------------------- 3.6/10.0 MB 1.7 MB/s eta 0:00:04
#    -------------- ------------------------- 3.7/10.0 MB 1.7 MB/s eta 0:00:04
#    -------------- ------------------------- 3.7/10.0 MB 1.6 MB/s eta 0:00:04
#    --------------- ------------------------ 3.8/10.0 MB 1.6 MB/s eta 0:00:04
#    --------------- ------------------------ 3.9/10.0 MB 1.6 MB/s eta 0:00:04
#    ---------------- ----------------------- 4.2/10.0 MB 1.7 MB/s eta 0:00:04
#    ---------------- ----------------------- 4.3/10.0 MB 1.7 MB/s eta 0:00:04
#    ----------------- ---------------------- 4.5/10.0 MB 1.8 MB/s eta 0:00:04
#    ------------------ --------------------- 4.7/10.0 MB 1.8 MB/s eta 0:00:04
#    ------------------ --------------------- 4.7/10.0 MB 1.8 MB/s eta 0:00:04
#    ------------------ --------------------- 4.8/10.0 MB 1.7 MB/s eta 0:00:04
#    ------------------- -------------------- 4.9/10.0 MB 1.8 MB/s eta 0:00:03
#    ------------------- -------------------- 4.9/10.0 MB 1.7 MB/s eta 0:00:03
#    -------------------- ------------------- 5.0/10.0 MB 1.7 MB/s eta 0:00:03
#    -------------------- ------------------- 5.2/10.0 MB 1.8 MB/s eta 0:00:03
#    -------------------- ------------------- 5.2/10.0 MB 1.7 MB/s eta 0:00:03
#    --------------------- ------------------ 5.3/10.0 MB 1.8 MB/s eta 0:00:03
#    --------------------- ------------------ 5.4/10.0 MB 1.8 MB/s eta 0:00:03
#    ---------------------- ----------------- 5.6/10.0 MB 1.8 MB/s eta 0:00:03
#    ----------------------- ---------------- 5.8/10.0 MB 1.8 MB/s eta 0:00:03
#    ----------------------- ---------------- 5.9/10.0 MB 1.8 MB/s eta 0:00:03
#    ------------------------ --------------- 6.1/10.0 MB 1.8 MB/s eta 0:00:03
#    ------------------------ --------------- 6.2/10.0 MB 1.8 MB/s eta 0:00:03
#    ------------------------ --------------- 6.2/10.0 MB 1.8 MB/s eta 0:00:03
#    ------------------------- -------------- 6.3/10.0 MB 1.8 MB/s eta 0:00:03
#    ------------------------- -------------- 6.5/10.0 MB 1.9 MB/s eta 0:00:02
#    -------------------------- ------------- 6.6/10.0 MB 1.9 MB/s eta 0:00:02
#    -------------------------- ------------- 6.7/10.0 MB 1.9 MB/s eta 0:00:02
#    -------------------------- ------------- 6.7/10.0 MB 1.9 MB/s eta 0:00:02
#    -------------------------- ------------- 6.7/10.0 MB 1.9 MB/s eta 0:00:02
#    --------------------------- ------------ 6.8/10.0 MB 1.8 MB/s eta 0:00:02
#    --------------------------- ------------ 6.8/10.0 MB 1.8 MB/s eta 0:00:02
#    --------------------------- ------------ 6.8/10.0 MB 1.8 MB/s eta 0:00:02
#    --------------------------- ------------ 6.9/10.0 MB 1.8 MB/s eta 0:00:02
#    --------------------------- ------------ 6.9/10.0 MB 1.8 MB/s eta 0:00:02
#    --------------------------- ------------ 7.0/10.0 MB 1.8 MB/s eta 0:00:02
#    --------------------------- ------------ 7.0/10.0 MB 1.8 MB/s eta 0:00:02
#    --------------------------- ------------ 7.0/10.0 MB 1.7 MB/s eta 0:00:02
#    ---------------------------- ----------- 7.0/10.0 MB 1.7 MB/s eta 0:00:02
#    ---------------------------- ----------- 7.0/10.0 MB 1.7 MB/s eta 0:00:02
#    ---------------------------- ----------- 7.1/10.0 MB 1.7 MB/s eta 0:00:02
#    ---------------------------- ----------- 7.2/10.0 MB 1.7 MB/s eta 0:00:02
#    ---------------------------- ----------- 7.2/10.0 MB 1.7 MB/s eta 0:00:02
#    ----------------------------- ---------- 7.3/10.0 MB 1.7 MB/s eta 0:00:02
#    ----------------------------- ---------- 7.4/10.0 MB 1.7 MB/s eta 0:00:02
#    ----------------------------- ---------- 7.4/10.0 MB 1.7 MB/s eta 0:00:02
#    ------------------------------ --------- 7.5/10.0 MB 1.7 MB/s eta 0:00:02
#    ------------------------------ --------- 7.7/10.0 MB 1.7 MB/s eta 0:00:02
#    ------------------------------- -------- 7.8/10.0 MB 1.7 MB/s eta 0:00:02
#    ------------------------------- -------- 7.8/10.0 MB 1.7 MB/s eta 0:00:02
#    -------------------------------- ------- 8.0/10.0 MB 1.7 MB/s eta 0:00:02
#    -------------------------------- ------- 8.1/10.0 MB 1.7 MB/s eta 0:00:02
#    --------------------------------- ------ 8.4/10.0 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.6/10.0 MB 1.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.8/10.0 MB 1.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.9/10.0 MB 1.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.0/10.0 MB 1.8 MB/s eta 0:00:01
#    ------------------------------------ --- 9.1/10.0 MB 1.8 MB/s eta 0:00:01
#    ------------------------------------ --- 9.2/10.0 MB 1.8 MB/s eta 0:00:01
#    ------------------------------------ --- 9.2/10.0 MB 1.8 MB/s eta 0:00:01
#    ------------------------------------- -- 9.4/10.0 MB 1.8 MB/s eta 0:00:01
#    -------------------------------------- - 9.6/10.0 MB 1.8 MB/s eta 0:00:01
#    -------------------------------------- - 9.6/10.0 MB 1.8 MB/s eta 0:00:01
#    -------------------------------------- - 9.7/10.0 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  9.9/10.0 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  10.0/10.0 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------- 10.0/10.0 MB 1.8 MB/s eta 0:00:00
# Downloading pandas-2.0.3-cp38-cp38-win_amd64.whl (10.8 MB)
#    ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#     --------------------------------------- 0.2/10.8 MB 3.1 MB/s eta 0:00:04
#    - -------------------------------------- 0.3/10.8 MB 3.8 MB/s eta 0:00:03
#    - -------------------------------------- 0.4/10.8 MB 3.3 MB/s eta 0:00:04
#    - -------------------------------------- 0.4/10.8 MB 3.3 MB/s eta 0:00:04
#    - -------------------------------------- 0.5/10.8 MB 2.2 MB/s eta 0:00:05
#    - -------------------------------------- 0.5/10.8 MB 1.9 MB/s eta 0:00:06
#    -- ------------------------------------- 0.6/10.8 MB 2.0 MB/s eta 0:00:06
#    --- ------------------------------------ 0.9/10.8 MB 2.3 MB/s eta 0:00:05
#    --- ------------------------------------ 0.9/10.8 MB 2.0 MB/s eta 0:00:05
#    --- ------------------------------------ 1.0/10.8 MB 2.0 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.2/10.8 MB 2.1 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.4/10.8 MB 2.2 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.4/10.8 MB 2.2 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.4/10.8 MB 2.2 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.5/10.8 MB 1.8 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.5/10.8 MB 1.8 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.6/10.8 MB 1.7 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.6/10.8 MB 1.7 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.6/10.8 MB 1.7 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.6/10.8 MB 1.7 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.6/10.8 MB 1.7 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.6/10.8 MB 1.7 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.6/10.8 MB 1.7 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.6/10.8 MB 1.7 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.6/10.8 MB 1.7 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.6/10.8 MB 1.7 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.6/10.8 MB 1.7 MB/s eta 0:00:06
#    ---------- ----------------------------- 2.8/10.8 MB 1.7 MB/s eta 0:00:05
#    ---------- ----------------------------- 2.9/10.8 MB 1.8 MB/s eta 0:00:05
#    ----------- ---------------------------- 3.0/10.8 MB 1.8 MB/s eta 0:00:05
#    ----------- ---------------------------- 3.0/10.8 MB 1.7 MB/s eta 0:00:05
#    ----------- ---------------------------- 3.0/10.8 MB 1.7 MB/s eta 0:00:05
#    ----------- ---------------------------- 3.1/10.8 MB 1.7 MB/s eta 0:00:05
#    ----------- ---------------------------- 3.2/10.8 MB 1.7 MB/s eta 0:00:05
#    ------------ --------------------------- 3.2/10.8 MB 1.7 MB/s eta 0:00:05
#    ------------ --------------------------- 3.3/10.8 MB 1.6 MB/s eta 0:00:05
#    ------------ --------------------------- 3.3/10.8 MB 1.7 MB/s eta 0:00:05
#    ------------ --------------------------- 3.3/10.8 MB 1.6 MB/s eta 0:00:05
#    ------------ --------------------------- 3.4/10.8 MB 1.6 MB/s eta 0:00:05
#    ------------ --------------------------- 3.5/10.8 MB 1.6 MB/s eta 0:00:05
#    ------------- -------------------------- 3.6/10.8 MB 1.6 MB/s eta 0:00:05
#    ------------- -------------------------- 3.6/10.8 MB 1.6 MB/s eta 0:00:05
#    ------------- -------------------------- 3.7/10.8 MB 1.6 MB/s eta 0:00:05
#    -------------- ------------------------- 3.8/10.8 MB 1.6 MB/s eta 0:00:05
#    -------------- ------------------------- 3.9/10.8 MB 1.6 MB/s eta 0:00:05
#    -------------- ------------------------- 3.9/10.8 MB 1.6 MB/s eta 0:00:05
#    -------------- ------------------------- 3.9/10.8 MB 1.6 MB/s eta 0:00:05
#    -------------- ------------------------- 4.0/10.8 MB 1.5 MB/s eta 0:00:05
#    -------------- ------------------------- 4.0/10.8 MB 1.5 MB/s eta 0:00:05
#    -------------- ------------------------- 4.0/10.8 MB 1.5 MB/s eta 0:00:05
#    -------------- ------------------------- 4.0/10.8 MB 1.5 MB/s eta 0:00:05
#    -------------- ------------------------- 4.0/10.8 MB 1.5 MB/s eta 0:00:05
#    -------------- ------------------------- 4.0/10.8 MB 1.5 MB/s eta 0:00:05
#    -------------- ------------------------- 4.0/10.8 MB 1.5 MB/s eta 0:00:05
#    -------------- ------------------------- 4.0/10.8 MB 1.5 MB/s eta 0:00:05
#    ----------------- ---------------------- 4.8/10.8 MB 1.6 MB/s eta 0:00:04
#    ------------------ --------------------- 4.9/10.8 MB 1.6 MB/s eta 0:00:04
#    ------------------ --------------------- 5.0/10.8 MB 1.6 MB/s eta 0:00:04
#    ------------------- -------------------- 5.2/10.8 MB 1.7 MB/s eta 0:00:04
#    ------------------- -------------------- 5.2/10.8 MB 1.7 MB/s eta 0:00:04
#    ------------------- -------------------- 5.2/10.8 MB 1.7 MB/s eta 0:00:04
#    ------------------- -------------------- 5.2/10.8 MB 1.7 MB/s eta 0:00:04
#    -------------------- ------------------- 5.5/10.8 MB 1.6 MB/s eta 0:00:04
#    --------------------- ------------------ 5.7/10.8 MB 1.7 MB/s eta 0:00:04
#    --------------------- ------------------ 5.8/10.8 MB 1.7 MB/s eta 0:00:03
#    --------------------- ------------------ 5.9/10.8 MB 1.7 MB/s eta 0:00:03
#    ---------------------- ----------------- 6.0/10.8 MB 1.7 MB/s eta 0:00:03
#    ---------------------- ----------------- 6.1/10.8 MB 1.7 MB/s eta 0:00:03
#    ---------------------- ----------------- 6.2/10.8 MB 1.7 MB/s eta 0:00:03
#    ----------------------- ---------------- 6.2/10.8 MB 1.7 MB/s eta 0:00:03
#    ----------------------- ---------------- 6.2/10.8 MB 1.7 MB/s eta 0:00:03
#    ----------------------- ---------------- 6.3/10.8 MB 1.6 MB/s eta 0:00:03
#    ----------------------- ---------------- 6.4/10.8 MB 1.6 MB/s eta 0:00:03
#    ----------------------- ---------------- 6.4/10.8 MB 1.6 MB/s eta 0:00:03
#    ------------------------ --------------- 6.5/10.8 MB 1.6 MB/s eta 0:00:03
#    ------------------------ --------------- 6.6/10.8 MB 1.6 MB/s eta 0:00:03
#    ------------------------ --------------- 6.6/10.8 MB 1.6 MB/s eta 0:00:03
#    ------------------------ --------------- 6.7/10.8 MB 1.6 MB/s eta 0:00:03
#    ------------------------- -------------- 6.7/10.8 MB 1.6 MB/s eta 0:00:03
#    ------------------------- -------------- 6.8/10.8 MB 1.6 MB/s eta 0:00:03
#    ------------------------- -------------- 6.9/10.8 MB 1.6 MB/s eta 0:00:03
#    ------------------------- -------------- 6.9/10.8 MB 1.6 MB/s eta 0:00:03
#    ------------------------- -------------- 7.0/10.8 MB 1.6 MB/s eta 0:00:03
#    -------------------------- ------------- 7.1/10.8 MB 1.6 MB/s eta 0:00:03
#    -------------------------- ------------- 7.1/10.8 MB 1.6 MB/s eta 0:00:03
#    -------------------------- ------------- 7.2/10.8 MB 1.6 MB/s eta 0:00:03
#    -------------------------- ------------- 7.2/10.8 MB 1.6 MB/s eta 0:00:03
#    --------------------------- ------------ 7.3/10.8 MB 1.6 MB/s eta 0:00:03
#    --------------------------- ------------ 7.4/10.8 MB 1.6 MB/s eta 0:00:03
#    --------------------------- ------------ 7.4/10.8 MB 1.6 MB/s eta 0:00:03
#    --------------------------- ------------ 7.5/10.8 MB 1.5 MB/s eta 0:00:03
#    ---------------------------- ----------- 7.6/10.8 MB 1.5 MB/s eta 0:00:03
#    ---------------------------- ----------- 7.7/10.8 MB 1.5 MB/s eta 0:00:03
#    ----------------------------- ---------- 7.9/10.8 MB 1.6 MB/s eta 0:00:02
#    ----------------------------- ---------- 7.9/10.8 MB 1.6 MB/s eta 0:00:02
#    ----------------------------- ---------- 8.0/10.8 MB 1.6 MB/s eta 0:00:02
#    ------------------------------ --------- 8.1/10.8 MB 1.6 MB/s eta 0:00:02
#    ------------------------------ --------- 8.2/10.8 MB 1.5 MB/s eta 0:00:02
#    ------------------------------ --------- 8.2/10.8 MB 1.5 MB/s eta 0:00:02
#    ------------------------------- -------- 8.4/10.8 MB 1.6 MB/s eta 0:00:02
#    ------------------------------- -------- 8.4/10.8 MB 1.5 MB/s eta 0:00:02
#    ------------------------------- -------- 8.5/10.8 MB 1.5 MB/s eta 0:00:02
#    ------------------------------- -------- 8.6/10.8 MB 1.6 MB/s eta 0:00:02
#    -------------------------------- ------- 8.6/10.8 MB 1.5 MB/s eta 0:00:02
#    -------------------------------- ------- 8.7/10.8 MB 1.5 MB/s eta 0:00:02
#    -------------------------------- ------- 8.8/10.8 MB 1.5 MB/s eta 0:00:02
#    -------------------------------- ------- 8.8/10.8 MB 1.5 MB/s eta 0:00:02
#    -------------------------------- ------- 8.9/10.8 MB 1.5 MB/s eta 0:00:02
#    --------------------------------- ------ 8.9/10.8 MB 1.5 MB/s eta 0:00:02
#    --------------------------------- ------ 9.0/10.8 MB 1.5 MB/s eta 0:00:02
#    --------------------------------- ------ 9.0/10.8 MB 1.5 MB/s eta 0:00:02
#    --------------------------------- ------ 9.1/10.8 MB 1.5 MB/s eta 0:00:02
#    --------------------------------- ------ 9.2/10.8 MB 1.5 MB/s eta 0:00:02
#    --------------------------------- ------ 9.2/10.8 MB 1.5 MB/s eta 0:00:02
#    ---------------------------------- ----- 9.2/10.8 MB 1.5 MB/s eta 0:00:02
#    ---------------------------------- ----- 9.3/10.8 MB 1.5 MB/s eta 0:00:02
#    ---------------------------------- ----- 9.4/10.8 MB 1.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.5/10.8 MB 1.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.6/10.8 MB 1.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.7/10.8 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------ --- 9.7/10.8 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------ --- 9.8/10.8 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------ --- 9.8/10.8 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------ --- 9.8/10.8 MB 1.5 MB/s eta 0:00:01
#    -------------------------------------- - 10.3/10.8 MB 1.5 MB/s eta 0:00:01
#    -------------------------------------- - 10.3/10.8 MB 1.5 MB/s eta 0:00:01
#    -------------------------------------- - 10.4/10.8 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------  10.5/10.8 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------  10.6/10.8 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------  10.6/10.8 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------  10.7/10.8 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------  10.7/10.8 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------  10.7/10.8 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------  10.8/10.8 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------  10.8/10.8 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 10.8/10.8 MB 1.5 MB/s eta 0:00:00
# Downloading patsy-0.5.6-py2.py3-none-any.whl (233 kB)
#    ---------------------------------------- 0.0/233.9 kB ? eta -:--:--
#    ------- -------------------------------- 41.0/233.9 kB 1.9 MB/s eta 0:00:01
#    --------------- ------------------------ 92.2/233.9 kB 1.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 174.1/233.9 kB 1.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 204.8/233.9 kB 1.6 MB/s eta 0:00:01
#    ---------------------------------------- 233.9/233.9 kB 1.1 MB/s eta 0:00:00
# Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#    ---------------------------------------- 0.0/345.4 kB ? eta -:--:--
#    - -------------------------------------- 10.2/345.4 kB ? eta -:--:--
#    -------------- ------------------------- 122.9/345.4 kB 1.0 MB/s eta 0:00:01
#    -------------------------- ------------- 225.3/345.4 kB 1.5 MB/s eta 0:00:01
#    --------------------------------- ------ 286.7/345.4 kB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 345.4/345.4 kB 1.4 MB/s eta 0:00:00
# Installing collected packages: tzdata, patsy, pandas, statsmodels
# Successfully installed pandas-2.0.3 patsy-0.5.6 statsmodels-0.14.1 tzdata-2024.1

# %%
import numpy as np 
ts_msAcc = np.load("testMSAccelerometer.npy")
ts_msGyr = np.load("testMSGyroscope.npy")
ts_labels = np.load("testLabels.npy")

OPEN_DOOR = 20
RUB_HANDS = 36

ts_labels_OPEN_DOOR_idx = ts_labels == OPEN_DOOR
ts_labels_RUB_HANDS_idx = ts_labels == RUB_HANDS

ts_msAcc_OPEN_DOOR = ts_msAcc[ts_labels_OPEN_DOOR_idx]
ts_msGyr_OPEN_DOOR = ts_msGyr[ts_labels_OPEN_DOOR_idx]

ts_msAcc_RUB_HANDS = ts_msAcc[ts_labels_RUB_HANDS_idx]
ts_msGyr_RUB_HANDS = ts_msGyr[ts_labels_RUB_HANDS_idx]

ts_labels_OPEN_DOOR = ts_labels[ts_labels_OPEN_DOOR_idx]
ts_labels_RUB_HANDS = ts_labels[ts_labels_RUB_HANDS_idx]

ts_msAcc_Two_Activities = np.concatenate((ts_msAcc_OPEN_DOOR, ts_msAcc_RUB_HANDS))
ts_msGyr_Two_Activities = np.concatenate((ts_msGyr_OPEN_DOOR, ts_msGyr_RUB_HANDS))
ts_labels_Two_Activities = np.concatenate((ts_labels_OPEN_DOOR, ts_labels_RUB_HANDS))

np.save("test_MSAccelerometer_OpenDoor_RubHands.npy", ts_msAcc_Two_Activities)
np.save("test_MSGyroscope_OpenDoor_RubHands.npy", ts_msGyr_Two_Activities)
np.save("test_labels_OpenDoor_RubHands.npy", ts_labels_Two_Activities)

print(ts_msAcc_Two_Activities.shape)
print(ts_msGyr_Two_Activities.shape)
print(ts_labels_Two_Activities.shape)
# Out:
# (90, 268, 3)
# (90, 268, 3)
# (90,)

# %%
data = np.load("trainAccelerometer.npy")
data1 = np.load("trainMSAccelerometer.npy")
data2 = np.load("trainLabels.npy")
print(data1.shape)
print(data2.shape)
# print(data)
print(data.shape)
data = np.reshape(data,(-1,1,data.shape[1]*3))
print(data.shape)
# Out:
# (2284, 268, 3)
# (2284,)
# (2284, 800, 3)
# (2284, 1, 2400)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Toy data with correct shape (batch_size, 108)
batch_size = 32
num_features = 108
num_classes = 3

# Generate random data and labels
data = np.random.random((batch_size, num_features)).astype(np.float32)
labels = np.random.randint(0, num_classes, size=(batch_size,))

for i in range(batch_size):
    if labels[i] == 0:
        labels[i] = 34;

print(labels)

# Define the model
model = Sequential(
    [
        tf.keras.Input(shape=(num_features,)),
        Dense(54, activation='relu'),
        Dense(18, activation='relu'),
        Dense(num_classes, activation='softmax')  # 3 classes for softmax
    ]
)

# Compile the model
model.compile(
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    optimizer=tf.keras.optimizers.Adam(0.001),
)

# Fit the model with the toy data
model.fit(data, labels, epochs=10)
# Out:
# [ 1 34  2  1 34  2  1 34 34 34  2 34  2  2  1 34  1  1  2  1 34 34  1  1
#   1 34 34  1  1 34 34 34]
# Epoch 1/10
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[8], line 38
#      32 model.compile(
#      33     loss=tf.keras.losses.SparseCategoricalCrossentropy(),
#      34     optimizer=tf.keras.optimizers.Adam(0.001),
#      35 )
#      37 # Fit the model with the toy data
# ---> 38 model.fit(data, labels, epochs=10)
#
# File ~\anaconda3\envs\tensorflow\lib\site-packages\keras\src\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# InvalidArgumentError: Graph execution error:
#
# Detected at node 'sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits' defined at (most recent call last):
#     File "C:\Users\inzi4\anaconda3\envs\tensorflow\lib\runpy.py", line 194, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "C:\Users\inzi4\anaconda3\envs\tensorflow\lib\runpy.py", line 87, in _run_code
#       exec(code, run_globals)
#     File "C:\Users\inzi4\anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "C:\Users\inzi4\anaconda3\envs\tensorflow\lib\site-packages\traitlets\config\application.py", line 992, in launch_instance
#       app.start()
#     File "C:\Users\inzi4\anaconda3\envs\tensorflow\lib\site-packages\ipykernel\kernelapp.py", line 701, in start
#       self.io_loop.start()
#     File "C:\Users\inzi4\anaconda3\envs\tensorflow\lib\site-packages\tornado\platform\asyncio.py", line 195, in start
#       self.asyncio_loop.run_forever()
#     File "C:\Users\inzi4\anaconda3\envs\tensorflow\lib\asyncio\windows_events.py", line 316, in run_forever
#       super().run_forever()
#     File "C:\Users\inzi4\anaconda3\envs\tensorflow\lib\asyncio\base_events.py", line 570, in run_forever
#       self._run_once()
#     File "C:\Users\inzi4\anaconda3\envs\tensorflow\lib\asyncio\base_events.py", line 1859, in _run_once
#       handle._run()
#     File "C:\Users\inzi4\anaconda3\envs\tensorflow\lib\asyncio\events.py", line 81, in _run
#       self._context.run(self._callback, *self._args)
#     File "C:\Users\inzi4\anaconda3\envs\tensorflow\lib\site-packages\ipykernel\kernelbase.py", line 534, in dispatch_queue
#       await self.process_one()
#     File "C:\Users\inzi4\anaconda3\envs\tensorflow\lib\site-packages\ipykernel\kernelbase.py", line 523, in process_one
#       await dispatch(*args)
#     File "C:\Users\inzi4\anaconda3\envs\tensorflow\lib\site-packages\ipykernel\kernelbase.py", line 429, in dispatch_shell
#       await result
#     File "C:\Users\inzi4\anaconda3\envs\tensorflow\lib\site-packages\ipykernel\kernelbase.py", line 767, in execute_request
#       reply_content = await reply_content
#     File "C:\Users\inzi4\anaconda3\envs\tensorflow\lib\site-packages\ipykernel\ipkernel.py", line 429, in do_execute
#       res = shell.run_cell(
#     File "C:\Users\inzi4\anaconda3\envs\tensorflow\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "C:\Users\inzi4\anaconda3\envs\tensorflow\lib\site-packages\IPython\core\interactiveshell.py", line 3009, in run_cell
#       result = self._run_cell(
#     File "C:\Users\inzi4\anaconda3\envs\tensorflow\lib\site-packages\IPython\core\interactiveshell.py", line 3064, in _run_cell
#       result = runner(coro)
#     File "C:\Users\inzi4\anaconda3\envs\tensorflow\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "C:\Users\inzi4\anaconda3\envs\tensorflow\lib\site-packages\IPython\core\interactiveshell.py", line 3269, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "C:\Users\inzi4\anaconda3\envs\tensorflow\lib\site-packages\IPython\core\interactiveshell.py", line 3448, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "C:\Users\inzi4\anaconda3\envs\tensorflow\lib\site-packages\IPython\core\interactiveshell.py", line 3508, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "C:\Users\inzi4\AppData\Local\Temp\ipykernel_22580\504998098.py", line 38, in <module>
#       model.fit(data, labels, epochs=10)
#     File "C:\Users\inzi4\anaconda3\envs\tensorflow\lib\site-packages\keras\src\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\inzi4\anaconda3\envs\tensorflow\lib\site-packages\keras\src\engine\training.py", line 1742, in fit
#       tmp_logs = self.train_function(iterator)
#     File "C:\Users\inzi4\anaconda3\envs\tensorflow\lib\site-packages\keras\src\engine\training.py", line 1338, in train_function
#       return step_function(self, iterator)
#     File "C:\Users\inzi4\anaconda3\envs\tensorflow\lib\site-packages\keras\src\engine\training.py", line 1322, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\inzi4\anaconda3\envs\tensorflow\lib\site-packages\keras\src\engine\training.py", line 1303, in run_step
#       outputs = model.train_step(data)
#     File "C:\Users\inzi4\anaconda3\envs\tensorflow\lib\site-packages\keras\src\engine\training.py", line 1081, in train_step
#       loss = self.compute_loss(x, y, y_pred, sample_weight)
#     File "C:\Users\inzi4\anaconda3\envs\tensorflow\lib\site-packages\keras\src\engine\training.py", line 1139, in compute_loss
#       return self.compiled_loss(
#     File "C:\Users\inzi4\anaconda3\envs\tensorflow\lib\site-packages\keras\src\engine\compile_utils.py", line 265, in __call__
#       loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     File "C:\Users\inzi4\anaconda3\envs\tensorflow\lib\site-packages\keras\src\losses.py", line 142, in __call__
#       losses = call_fn(y_true, y_pred)
#     File "C:\Users\inzi4\anaconda3\envs\tensorflow\lib\site-packages\keras\src\losses.py", line 268, in call
#       return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     File "C:\Users\inzi4\anaconda3\envs\tensorflow\lib\site-packages\keras\src\losses.py", line 2354, in sparse_categorical_crossentropy
#       return backend.sparse_categorical_crossentropy(
#     File "C:\Users\inzi4\anaconda3\envs\tensorflow\lib\site-packages\keras\src\backend.py", line 5762, in sparse_categorical_crossentropy
#       res = tf.nn.sparse_softmax_cross_entropy_with_logits(
# Node: 'sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits'
# Received a label value of 34 which is outside the valid range of [0, 3).  Label values: 2 2 1 2 1 1 2 34 1 34 1 1 34 34 1 34 34 2 34 1 34 1 1 2 34 1 34 34 34 34 34 1
# 	 [[{{node sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits}}]] [Op:__inference_train_function_926]

# %%
arr1 = np.zeros(5)
arr2 = np.zeros(5)   
arr1[0] = 2.0;
arr2[0] = 2.0;
arr1[1] = 3.0;
arr2[1] = 3.0;
arr1[2] = 1.0;
arr2[2] = 1.0;
indices = np.random.permutation(5)
arr1 = arr1[indices]
arr2 = arr2[indices]
print(arr1)
print(arr2)
# Out:
# [0. 1. 0. 3. 2.]
# [0. 1. 0. 3. 2.]
